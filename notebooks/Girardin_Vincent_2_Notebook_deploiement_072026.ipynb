# %% [markdown]
# # Confirmez vos compétences en MLOps (partie 2/2)

# %% [markdown]
# # Imports dépendances

# %%
# %pip install -e .

# %%
pip list
# Out:
# Package                            Version      Editable project location
# ---------------------------------- ------------ -------------------------------------------------------------------------------------------
# aiohappyeyeballs                   2.7.1
# aiohttp                            3.14.3
# aiosignal                          1.4.0
# alembic                            1.18.5
# annotated-doc                      0.0.4
# annotated-types                    0.8.0
# anyio                              4.14.2
# asttokens                          3.0.2
# attrs                              26.1.0
# blinker                            1.9.0
# cachetools                         7.1.6
# category_encoders                  2.10.0
# certifi                            2026.7.22
# cffi                               2.1.0
# charset-normalizer                 3.4.9
# click                              8.4.2
# cloudpickle                        3.1.2
# ...

# %%
import joblib
import os
from pathlib import Path

import pandas as pd

# %% [markdown]
# # Extraire le modèle

# %%
# # 1. Création du dossier artifacts
# os.makedirs("artifacts", exist_ok=True)

# # 2. Exportation directe du pipeline/modèle
# # (Remplacez 'best_pipeline' par le nom exact de votre variable)
# joblib.dump(new_pipeline_xgb, "artifacts/best_model_pipeline.joblib")

# print("✅ Artefact du modèle sauvegardé avec succès dans artifacts/best_model_pipeline.joblib")

# %%
print("📋 Fichiers et dossiers dans le projet actuel :")
for root, dirs, files in os.walk("."):
    # On ignore le dossier de l'environnement virtuel .venv
    if ".venv" in root or ".git" in root:
        continue
    for file in files:
        if file.endswith((".db", ".pkl", ".joblib", ".tar.gz")):
            print(" 📄", os.path.join(root, file))
# Out:
# 📋 Fichiers et dossiers dans le projet actuel :

# %%
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()

# Chemin vers le modèle
MODEL_PATH = PROJECT_ROOT / "artifacts" / "best_model_pipeline.joblib"

print(f"📍 Chemin du modèle : {MODEL_PATH}")

# Chargement du modèle
pipeline = joblib.load(MODEL_PATH)
print("✅ Modèle chargé avec succès !")
# Out:
# 📍 Chemin du modèle : c:\Users\15GIRAV\Moi\Boulot\OpenClassrooms\P8_Confirmez_vos_competences_en_MLOPS_partie_2_2\artifacts\best_model_pipeline.joblib
# ✅ Modèle chargé avec succès !
